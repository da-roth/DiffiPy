# %%
import numpy as np

x = 1.7
a = np.sqrt(2)
y = np.exp(x * a)

print(y)
# Out:
# 11.069162135812496

# %%
import os
import sys

os.getcwd()  # Check the current working directory
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import src.diffipy.diffipy as dp

# %%
import src.diffipy.diffipy as dp

x = 1.7
a = dp.sqrt(2)
y = dp.exp(x * a)

print(y)
print(y.eval())
# Out:
# exp((1.7 * sqrt(2)))
# 11.069162135812496

# %%
import src.diffipy.diffipy as np

x = 1.7
a = np.sqrt(2)
y = np.exp(x * a)

print(y)
print(y.eval())
# Out:
# exp((1.7 * sqrt(2)))
# 11.069162135812496

# %%
x_value = 1.7
x= dp.variable(x_value)
a = dp.sqrt(2)
y = dp.exp(x * a)

result = y.eval()
derivative = y.grad(x)

print("{:<12} {:<12} {:<12}".format('Backend', 'Result', 'Gradient'))
print("{:<12} {:<12.6f} {:<12.6f}".format("numpy", result, derivative))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 7
#       4 y = dp.exp(x * a)
#       6 result = y.eval()
# ----> 7 derivative = y.grad(x)
#       9 print("{:<12} {:<12} {:<12}".format('Backend', 'Result', 'Gradient'))
#      10 print("{:<12} {:<12.6f} {:<12.6f}".format("numpy", result, derivative))
#
# File c:\Users\DanielPrivateGitHub\Documents\GitHub\DiffiPy\DifferentiationInterface\src\diffipy\Node.py:113, in Node.grad(self, diffDirection)
#     111     diffDirection = self.get_inputs_with_diff()
#     112 instance_grad_class = grad_class(self, diffDirection)
# --> 113 return instance_grad_class.backend_specific_grad()
#
# File c:\Users\DanielPrivateGitHub\Documents\GitHub\DiffiPy\DifferentiationInterface\src\diffipy\backends\numpy\NodesNumpy.py:118, in DifferentiationNodeNumpy.backend_specific_grad(self)
#     115 else:
#     116     # Handle the case where self.diffDirection is a single diff direction
#     117     original_value = self.diffDirection.value
# --> 118     self.diffDirection.value = original_value + h
#     119     result_h = self.Run()
#     120     gradient = (result_h - result) / h
#
# NameError: name 'h' is not defined

# %%
dp.setBackend('torch')
x_value = 1.7
x= dp.variable(x_value)
a = dp.sqrt(2)

y = dp.exp(x * a)

result = y.eval()
derivative = y.grad(x)

print("{:<12} {:<12} {:<12}".format('Backend', 'Result', 'Gradient'))
print("{:<12} {:<12.6f} {:<12.6f}".format("torch", result, derivative))
# Out:
# Backend      Result       Gradient
# torch        11.069163    15.654160

# %%
backend_array = ['numpy', 'torch', 'tensorflow', 'jax']
print("{:<12} {:<12} {:<12}".format('Backend', 'Result', 'Gradient'))

for backend in backend_array:
    dp.setBackend(backend)

    x_value = 1.7
    y_value = 0.7
    x = dp.variable(x_value)
    y = dp.variable(y_value)
    a = dp.sqrt(2)
    f = dp.exp(x * a) + dp.exp(y)
    
    result = f.eval()
    derivative = f.grad()

    print("{:<12} {:<12.6f} {:<12}".format(backend, result, str(derivative)))
# Out:
# Backend      Result       Gradient
# numpy        13.082915    [15.654269908971228, 2.0137627762650823]
# torch        13.082916    [15.654160499572754, 2.0137526988983154]
# tensorflow   13.082916    [15.6541605, 2.0137527]
# jax          13.082915    [15.654159545898438, 2.0137526988983154]

# %%
# Differentiation in a specific direction .grad(y)
backend_array = ['numpy', 'torch', 'tensorflow', 'jax']
print("{:<12} {:<12} {:<12}".format('Backend', 'Result', 'Gradient'))

for backend in backend_array:
    dp.setBackend(backend)

    x_value = 1.7
    y_value = 0.7
    x = dp.variable(x_value)
    y = dp.variable(y_value)
    a = dp.sqrt(2)
    f = dp.exp(x * a) + dp.exp(y)
    
    result = f.eval()
    derivative = f.grad(y)

    print("{:<12} {:<12.6f} {:<12}".format(backend, result, str(derivative)))
# Out:
# Backend      Result       Gradient
# numpy        13.082915    2.0137627762650823
# torch        13.082916    2.0137526988983154
# tensorflow   13.082916    2.0137527
# jax          13.082915    2.0137527

# %%
dp.setBackend('numpy')

x_value = 1.0
y_value = 2.0
x = dp.variable(x_value)
y = dp.variable(y_value)
a = dp.sqrt(2)
f = x*x*x - (y)*y*y*y*y*y - 2*x*y

result = f.eval()
derivative = f.hessian()

# print("{:<12} {:<12} {:<12}".format('Backend', 'Result', 'Gradient'))
# print("{:<12} {:<12.6f} {:<12.6f}".format("torch", result, derivative))
print(derivative)
# Out:
# Directions after perturbation: [<src.diffipy.NodesVariables.VariableNode object at 0x0000021998D41AB0>, <src.diffipy.NodesVariables.VariableNode object at 0x00000219A9139DE0>]
# Gradient at perturbed point: [  -0.99909993 -194.0242016 ]
# Directions after perturbation: [<src.diffipy.NodesVariables.VariableNode object at 0x0000021998D41AB0>, <src.diffipy.NodesVariables.VariableNode object at 0x00000219A9139DE0>]
# Gradient at perturbed point: [  -0.99989999 -194.0720112 ]
# [[   6.00060019   -1.99999874]
#  [  -1.99999874 -480.09600704]]
