# %% [markdown]
# <a href="https://colab.research.google.com/github/da-roth/DiffiPy/blob/main/DifferentiationInterface/examples-colab/introduction_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install DiffiPy
# !pip install diffipy
import diffipy
# Out:
# Requirement already satisfied: diffipy in c:\users\danielprivategithub\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.0.7)
# Requirement already satisfied: numpy in c:\users\danielprivategithub\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from diffipy) (1.23.4)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\DanielPrivateGitHub\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Original Code Using numpy
import numpy as np

x = 1.7
a = np.sqrt(2)
y = np.exp(x * a)

print(y)
# Out:
# 11.069162135812496

# %%
# Option 1: Direct Replacement of Prefixes
import diffipy as dp

x = 1.7
a = dp.sqrt(2)
y = dp.exp(x * a)

print(y)
print(y.eval()) #The addition of y.eval() is necessary to obtain the float result, otherwise, it will display the computational graph.
# Out:
# exp((1.7 * sqrt(2)))
# 11.069162135812496

# %%
# Option 2: Import 'diffipy' as 'np'
import diffipy as np

x = 1.7
a = np.sqrt(2)
y = np.exp(x * a)

print(y)
print(y.eval()) #The addition of y.eval() is necessary to obtain the float result, otherwise, it will display the computational graph.
# Out:
# exp((1.7 * sqrt(2)))
# 11.069162135812496

# %%
backend_array = ['numpy', 'torch', 'tensorflow', 'jax']
print("{:<12} {:<12} {:<12}".format('Backend', 'Result', 'Gradient'))

for backend in backend_array:
    dp.setBackend(backend)

    x_value = 1.7
    y_value = 0.7
    x = dp.variable(x_value)
    y = dp.variable(y_value)
    a = dp.sqrt(2)
    f = dp.exp(x * a) + dp.exp(y)
    
    result = f.eval()
    derivative = f.grad()

    print("{:<12} {:<12.6f} {:<12}".format(backend, result, str(derivative)))
# Out:
# Backend      Result       Gradient
# numpy        13.082915    [15.654269908971228, 2.0137627762650823]
# torch        13.082916    [15.654160499572754, 2.0137526988983154]
# tensorflow   13.082916    [15.6541605, 2.0137527]
# jax          13.082915    [15.654159545898438, 2.0137526988983154]

# %%
# Differentiation in a specific direction
backend_array = ['numpy', 'torch', 'tensorflow', 'jax']
print("{:<12} {:<12} {:<44}{:<24}".format('Backend', 'Result', 'Gradient', 'Hessian'))

for backend in backend_array:
    dp.setBackend(backend)

    x_value = 1.7
    y_value = 0.7
    x = dp.variable(x_value)
    y = dp.variable(y_value)
    a = dp.sqrt(2)
    f = dp.exp(x * a) + dp.exp(y)
    
    result = f.eval()
    derivative = f.grad(y)
    hessian = f.hessian()
    print("{:<12} {:<12.6f} {:<44} {:<24}".format(backend, result, str(grad), dp.HessianString(hessian)))
# Out:
# Backend      Result       Gradient                                    Hessian
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 17
#      15 result = f.eval()
#      16 derivative = f.grad(y)
# ---> 17 hessian = f.hessian()
#      18 print("{:<12} {:<12.6f} {:<44} {:<24}".format(backend, result, str(grad), dp.HessianString(hessian)))
#
# AttributeError: 'AddNode' object has no attribute 'hessian'
